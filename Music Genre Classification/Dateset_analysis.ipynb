# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import tqdm
import pickle

# %%
SOUND_FOLDER_training = "./Audio_Dataset/training_data"
SOUND_FOLDER_testing = "./Audio_Dataset/testing_data"
FEAT_FOLDER = "./Features"

# %% [markdown]
# ## **Dataset analysis**

# %%
# Create Dataframe for Training Data
df_training = pd.DataFrame(columns=['path', 'file_name', 'class'])
print(df_training)
# Out:
# Empty DataFrame
# Columns: [path, file_name, class]
# Index: []

# %%
# Create Dataframe for Testing Data
df_testing = pd.DataFrame(columns=['path', 'file_name', 'class'])
print(df_testing)
# Out:
# Empty DataFrame
# Columns: [path, file_name, class]
# Index: []

# %%
path_training = os.path.join(SOUND_FOLDER_training)
path_testing = os.path.join(SOUND_FOLDER_testing)

# %%
# Retrieve list of files related to Training Data
for (root, dirs, file) in os.walk(path_training):
    for f in file:
      if '.wav' in f:
        path_complete = root+"/"+f
        db_new_row = {'path':path_complete}
        db_new_row['file_name'] = os.path.basename(path_complete).split('/')[-1]
        db_new_row['class'] = os.path.split(path_complete)[0].split("/")[-1]
        s = pd.Series(db_new_row)
        df_training = pd.concat([df_training, s.to_frame().T], ignore_index=True)
df_training
# Out:
#                                                   path         file_name  \
# 0    ./Audio_Dataset/training_data/disco/disco.0005...   disco.00052.wav
# 1    ./Audio_Dataset/training_data/disco/disco.0004...   disco.00046.wav
# 2    ./Audio_Dataset/training_data/disco/disco.0004...   disco.00047.wav
# 3    ./Audio_Dataset/training_data/disco/disco.0005...   disco.00053.wav
# 4    ./Audio_Dataset/training_data/disco/disco.0004...   disco.00045.wav
# ..                                                 ...               ...
# 155  ./Audio_Dataset/training_data/hiphop/hiphop.00...  hiphop.00010.wav
# 156  ./Audio_Dataset/training_data/hiphop/hiphop.00...  hiphop.00006.wav
# 157  ./Audio_Dataset/training_data/hiphop/hiphop.00...  hiphop.00012.wav
# 158  ./Audio_Dataset/training_data/hiphop/hiphop.00...  hiphop.00013.wav
# 159  ./Audio_Dataset/training_data/hiphop/hiphop.00...  hiphop.00007.wav
#
#       class
# 0     disco
# 1     disco
# 2     disco
# 3     disco
# 4     disco
# ..      ...
# 155  hiphop
# 156  hiphop
# 157  hiphop
# 158  hiphop
# 159  hiphop
#
# [160 rows x 3 columns]

# %%
# Retrieve list of files related to Testing Data
for (root, dirs, file) in os.walk(path_testing):
    for f in file:
      if '.wav' in f:
        path_complete = root+"/"+f
        db_new_row = {'path':path_complete}
        db_new_row['file_name'] = os.path.basename(path_complete).split('/')[-1]
        db_new_row['class'] = os.path.split(path_complete)[0].split("/")[-1]
        s = pd.Series(db_new_row)
        df_testing = pd.concat([df_testing, s.to_frame().T], ignore_index=True)
df_testing
# Out:
#                                                  path         file_name  \
# 0   ./Audio_Dataset/testing_data/disco/disco.00091...   disco.00091.wav
# 1   ./Audio_Dataset/testing_data/disco/disco.00085...   disco.00085.wav
# 2   ./Audio_Dataset/testing_data/disco/disco.00084...   disco.00084.wav
# 3   ./Audio_Dataset/testing_data/disco/disco.00090...   disco.00090.wav
# 4   ./Audio_Dataset/testing_data/disco/disco.00086...   disco.00086.wav
# 5   ./Audio_Dataset/testing_data/disco/disco.00092...   disco.00092.wav
# 6   ./Audio_Dataset/testing_data/disco/disco.00093...   disco.00093.wav
# 7   ./Audio_Dataset/testing_data/disco/disco.00087...   disco.00087.wav
# 8   ./Audio_Dataset/testing_data/disco/disco.00083...   disco.00083.wav
# 9   ./Audio_Dataset/testing_data/disco/disco.00097...   disco.00097.wav
# 10  ./Audio_Dataset/testing_data/disco/disco.00096...   disco.00096.wav
# 11  ./Audio_Dataset/testing_data/disco/disco.00082...   disco.00082.wav
# 12  ./Audio_Dataset/testing_data/disco/disco.00094...   disco.00094.wav
# 13  ./Audio_Dataset/testing_data/disco/disco.00080...   disco.00080.wav
# 14  ./Audio_Dataset/testing_data/disco/disco.00081...   disco.00081.wav
# 15  ./Audio_Dataset/testing_data/disco/disco.00095...   disco.00095.wav
# 16  ./Audio_Dataset/testing_data/disco/disco.00098...   disco.00098.wav
# 17  ./Audio_Dataset/testing_data/disco/disco.00099...   disco.00099.wav
# 18  ./Audio_Dataset/testing_data/disco/disco.00089...   disco.00089.wav
# 19  ./Audio_Dataset/testing_data/disco/disco.00088...   disco.00088.wav
# 20  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00082.wav
# 21  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00096.wav
# 22  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00097.wav
# 23  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00083.wav
# 24  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00095.wav
# 25  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00081.wav
# 26  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00080.wav
# 27  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00094.wav
# 28  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00090.wav
# 29  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00084.wav
# 30  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00085.wav
# 31  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00091.wav
# 32  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00087.wav
# 33  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00093.wav
# 34  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00092.wav
# 35  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00086.wav
# 36  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00088.wav
# 37  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00089.wav
# 38  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00099.wav
# 39  ./Audio_Dataset/testing_data/hiphop/hiphop.000...  hiphop.00098.wav
#
#      class
# 0    disco
# 1    disco
# 2    disco
# 3    disco
# 4    disco
# 5    disco
# 6    disco
# 7    disco
# 8    disco
# 9    disco
# 10   disco
# 11   disco
# 12   disco
# 13   disco
# 14   disco
# 15   disco
# 16   disco
# 17   disco
# 18   disco
# 19   disco
# 20  hiphop
# 21  hiphop
# 22  hiphop
# 23  hiphop
# 24  hiphop
# 25  hiphop
# 26  hiphop
# 27  hiphop
# 28  hiphop
# 29  hiphop
# 30  hiphop
# 31  hiphop
# 32  hiphop
# 33  hiphop
# 34  hiphop
# 35  hiphop
# 36  hiphop
# 37  hiphop
# 38  hiphop
# 39  hiphop

# %%
print(df_training.loc[1,['path', 'file_name']])
print(df_testing.loc[1,['path','file_name']])
# Out:
# path         ./Audio_Dataset/training_data/disco/disco.0004...
# file_name                                      disco.00046.wav
# Name: 1, dtype: object
# path         ./Audio_Dataset/testing_data/disco/disco.00085...
# file_name                                      disco.00085.wav
# Name: 1, dtype: object

# %%
# Count occurrences in classes
df_classes = pd.DataFrame(columns=['class','num'])
count = df_training['class'].value_counts(dropna=False)
classes = count.index.values
values = count.values

df_classes['class'] = classes
df_classes['num'] = count.values

print(df_classes)
# Out:
#     class  num
# 0   disco   80
# 1  hiphop   80

# %%
plot = sns.barplot(x=classes, y=values)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
# Out:
# /var/folders/vv/hj__r4qd6db628cs1n1g0ldm0000gn/T/ipykernel_2492/2840464404.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
# [Text(0, 0, 'disco'), Text(1, 0, 'hiphop')]

# %% [markdown]
# ## **Save Label file**

# %%
path_training = os.path.join(SOUND_FOLDER_training)
print("save labels in ")

if os.path.isdir(path_training):
    # exists
    print("found")
else:
    # doesn’t exist
    print(path_training + " Not found")
    os.mkdir(path_training)
    print(path_training + " Created")


print("save labels to -> "+path_training + "label_training.csv")
path_to_save = os.path.join(path_training, "label_training.csv")
df_training.to_csv(path_or_buf=path_to_save, index=False)
# Out:
# save labels in
# found
# save labels to -> ./Audio_Dataset/training_datalabel_training.csv

# %%
path_testing = os.path.join(SOUND_FOLDER_testing)
print("save labels in ")

if os.path.isdir(path_testing):
    # exists
    print("found")
else:
    # doesn’t exist
    print(path_testing + " Not found")
    os.mkdir(path_testing)
    print(path_testing + " Created")


print("save labels to -> "+path_testing + "label_testing.csv")
path_to_save = os.path.join(path_testing, "label_testing.csv")
df_testing.to_csv(path_or_buf=path_to_save, index=False)
# Out:
# save labels in
# found
# save labels to -> ./Audio_Dataset/testing_datalabel_testing.csv

# %%
path_classes = os.path.join("./Audio_Dataset")
print("Save classes in")

if os.path.isdir(path_classes):
    # exists
    print("found")
else:
    # doesn't exist
    print(path_classes + " Not found")
    os.mkdir(path_classes)
    print(path_classes + " Created")

print("save classes to -> "+path_classes + "classes.csv")
path_to_save = os.path.join(path_classes, "classes.csv")
df_classes.to_csv(path_or_buf=path_to_save, index=False)
# Out:
# Save classes in
# found
# save classes to -> ./Audio_Datasetclasses.csv
